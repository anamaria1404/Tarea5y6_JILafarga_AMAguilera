# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Ivan Lafarga Lizarraga, Ana María Aguilera Gómez
#
# **Fecha:** 11 de Octubre del 2021.
#
# **Expediente** : 708989 y 720567.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 6: Clase 10

# %% [markdown]
# ### Link de Github:
# > https://github.com/ivanLafarga/Tarea5y6_JILafarga_AMAguilera

# %% [markdown]
# # <font> **Tarea 6**
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:

# %% [markdown]
# ### <font> **Ejercicio 1:**
# > 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %%
#Librerías:
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
# %matplotlib inline
from scipy.stats import binom

# %% [markdown]
# # Soluciones Ivan

# %%
# Código de solución 
x =np.arange(0,1,0.01)
#función objetivo:
funcion = lambda x: 30*((x**2)-(2*x**3)+(x**4)) 
#encuentra el máximo de la función:
c = float(funcion(optimize.fmin(lambda x:-funcion(x), 0, disp=False))) #clase 10
t = lambda x: c * np.sin((np.pi)*x) 
plt.figure(figsize=[6,5]) 
plt.title('Grafica de $t(x)\geq f(x)$',fontsize=14)
plt.xlabel('Rango',fontsize=14)
plt.ylabel('Densidad de probabilidad',fontsize=14)
plt.plot(x,funcion(x), label='$f(x)$',color="red",lw=4)
plt.plot(x,t(x),label='$t(x)$',color="green",lw=4,ls="-.")
plt.grid()
plt.legend();
plt.show()
print('El máximo de la función es:',c)
# Out:
# El máximo de la función es: 1.875

# %% [markdown]
# ### Respuesta Ivan
# La función que vemos en color rojo t(x) podemos confirmar vusialmente t(x) > f(x) en la mayoria de los puntos que la componene excepto en el límite superior pues este representan perfectamente la condición "≥" la cual se sigue cumpliendo.

# %% [markdown]
# # Soluciones Ana

# %%
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) #máximo de la func.
t = lambda x: max_f*np.sin(x*np.pi) # función constante t
max_t = f(optimize.fmin(lambda x:-t(x),0,disp=False)) #máximo

x = np.arange(0,1,0.01)  # Rango para graficar
print('Puntos máximos f(x) y t(x):',max_f,max_t)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend();
# Out:
# Puntos máximos f(x) y t(x): [1.875] [1.875]

# %% [markdown]
# Se puede observar que t(x) > f(x)

# %% [markdown]
# ### <font> **Ejercicio 2:**
# > 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# ### Respuesta Ivan

# %% [markdown]
# Para encontrar la función de densidad g(x) recurrimos a las integrales por lo que se integra la función $t(x)$ que es $a \sin(\pi x)$ para conocer c:
# > Integral:
# $$\int_{0}^{1} t(x) dx = \int_{0}^{1} a \sin(\pi x) dx$$
# > $a$ se toma como constantea y aplicamos integración por sustitución siendo $u = \pi x$
# > Entonces:
# $$\frac{a}{\pi} \int_{0}^{\pi}  \sin(u) du$$
# > Resultado: $$\frac{a}{\pi} [-\cos(u)]_{0}^{\pi}$$
# $$ c= \frac{2a}{\pi} $$
# > Por lo que para conocer g(x) sólo se divide $t(x)$ entre $c$:
# $$\frac{t(x)}{c} = \frac{a \sin(\pi x)}{\frac{2a}{\pi}} = \frac{\pi \sin(\pi x)}{2}$$
# Tenemos : <span style="color:Red"> $$g(x) = \frac{\pi \sin(\pi x)}{2}$$

# %% [markdown]
# # Soluciones Ana

# %% [markdown]
# Integrar y obtener c
# $$c = \int_{0}^{1} t(x) dx$$
# $$ c= \int_{0}^{1} a \sin(\pi x) dx$$
# $$c =\frac{a}{\pi} [-\cos(\pi x)]_{0}^{\pi}$$
# $$ c= \frac{2a}{\pi} $$
# Una vez encontrado c, se obtiene g(x):
# $$g(x) = \frac{t(x)}{c}$$
# $$g(x) =  \frac{a \sin(\pi x)}{\frac{2a}{\pi}} $$
# $$ g(x) = \frac{\pi \sin(\pi x)}{2}$$

# %% [markdown]
# ### <font > **Ejercicio 3:**
# > 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# ### Respuesta Ivan

# %% [markdown]
# Para conocer G(x) primero se integra el resuultado anterior que es: $$g(x) = \frac{\pi \sin(\pi x)}{2}$$
# > Integral:
# $$\int_{0}^{x}\frac{\pi \sin(\pi x)}{2} dx = \frac{\pi}{2}\int_{0}^{x} \sin(\pi x) dx$$
# > ahora se aplica integración por sustitución siendo $u = \pi x$
# > Entonces:
# $$\frac{\pi}{2}\frac{1}{\pi} \int_{0}^{x\pi}  \sin(u) du = \frac{1}{2}\int_{0}^{x\pi}  \sin(u) du$$
# > Integrando se obtiene que:
# $$\frac{1}{2}[-\cos(u)]_{0}^{x\pi} = \frac{1}{2}[-\cos(x\pi)]_{0}^{x\pi} = \frac{1}{2}(-\cos(x\pi)+1)$$
#  Por lo que: <span style="color:red"> $$G(x) = \frac{1}{2}(-\cos(x\pi)+1)$$
#
# > Ahora a partir de $G(x)$ se obtiene el valor de $x$:
# $$G(x) = \frac{1}{2}(-\cos(x\pi)+1)$$
# > Se iguala a $u$ para obtener la inversa:
# $$u = \frac{1}{2}(-\cos(x\pi)+1)$$
# > Entonces:
# $$ \cos(x\pi) = 1-2u$$
# > Por lo que:
# $$x\pi = arccos(1-2u)$$
# <span style="color:red">  $$x = \frac{arccos(1-2u)}{\pi} $$

# %% [markdown]
# # Soluciones Ana

# %% [markdown]
# $$g(x) = \frac{\pi \sin(\pi x)}{2}$$
# Integrar para encontrar G(x)
# $$G(x)=\frac{\pi}{2}\int_{0}^{x} \sin(\pi x) dx$$
# $$G(x) =\frac{1}{2}[-\cos(\pi x)]_{0}^{x}$$
# $$G(x) = \frac{1}{2}(-\cos(x\pi)+1)$$
# Para generar las variables aleatorias se despeja x, igualando G(x) a u:
# $$u=\frac{1}{2}(-\cos(x\pi)+1)$$
# $$1-2u=\cos(\pi x)$$
# $$\arccos(1-2u)=\pi x$$
# $$x=\frac{\arccos(1-2u)}{\pi}$$

# %% [markdown]
# ### <font> **Ejercicio 4:**
# > 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:

# %% [markdown]
# # Soluciones Ivan

# %%
# Código de solución 
N = 10000
x = np.arange(0,1,0.01)
r = np.random.rand(N)
plt.figure(figsize=[6,5]) 
plt.title("Gráfica",fontsize=14)
f1 = lambda x: (np.pi*np.sin((np.pi)*x))/2
plt.plot(x,f1(x),color="green",lw=5,ls="-")
f2 = lambda r: (np.arccos(1-2*r))/np.pi
plt.hist(f2(r),bins=50,density=True,color='blue',linestyle='dashed')
plt.xlabel('Rango',fontsize=14)
plt.ylabel('Densidad de probabilidad',fontsize=14)
plt.grid()
#plt.legend();
plt.show()

# %% [markdown]
# ### Respuesta Ivan
# Las barras se comportan de similar manera como se ve en la curva asi como entre más puntos aleatorios son más cercano a la distribución de g(x) que trata de imitar con 10000 puntos aleatorios esta distribución.

# %% [markdown]
# # Soluciones Ana

# %%
def comparar_aleatorios_densidad(f,Finv,N):
    u = np.random.uniform(0,1,N)
    f_rand = Finv(u)
    x=np.arange(0,1,.01)
    g = f(x)
    plt.hist(f_rand,density=True, bins=40)
    plt.plot(x,g, label='g(x)')
    plt.legend()
    plt.show()
    
g = lambda x: (np.pi/2)*np.sin(np.pi*x)
G_inv=lambda u: (1/np.pi)*np.arccos(-2*u+1)
N=10000
comparar_aleatorios_densidad(g,G_inv,N)

# %% [markdown]
# Las barras generadas tienen una buena aproximación a la curva, mismas que mejoran aún más entre mayor sea el N.

# %% [markdown]
# ### <font color ='blue'> **Ejercicio 5:**
# > 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:

# %% [markdown]
# ### Soluciones Ivan

# %%
# Código de solución 
# Función de aceptación y rechazo usando compresión de listas (vista en clase 10)
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'oc') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
     for i in range(len(R1))] 
    plt.show()
    
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    
    return x

# Parámetros de la función 
N = 500  # número de puntos
x =np.arange(0,1,0.01)
# Función objetivo 
f = lambda x: 30*(x**2 -2 * x**3 + x**4) 
# Máximo de la función f
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
plt.plot(x,f(x))

t = lambda x: a * np.sin(np.pi*x)
plt.plot(x,f(x),'black',lw=5,label='f(x)')
plt.plot(x,t(x),'green',lw=5,label='t(x)')
plt.legend()
plt.title("Gráfica",fontsize=14)
#plt.xlabel('Rango',fontsize=14)
#plt.ylabel('Densidad de probabilidad',fontsize=14)
R1 = np.random.rand(N)
R2 = np.random.rand(N)
Acep_rechazo(R2,R1,f,t)
plt.show()

# %% [markdown]
# ### Respuesta Ivan
# Con método de aceptación y rechazo podemos ver como los puntos debajo de la función f(x) la mayoría de los puntos en azul han sido aceptados por esta simulación

# %% [markdown]
# ## Soluciones Ana

# %%
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <= f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]                
    plt.show()
    
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) #máximo de la func.
t = lambda x: max_f*np.sin(x*np.pi) # función constante t
max_t = f(optimize.fmin(lambda x:-t(x),0,disp=False)) #máximo

x = np.arange(0,1,0.01)  # Rango para graficar
print('Puntos máximos f(x) y t(x):',max_f,max_t)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend();

# Validación del método
N = 1000 
R2 = np.random.rand(N)
R1 = np.random.rand(N)

aleatorias = Acep_rechazo(R2,R1,f,t)
aleatorias
# Out:
# Puntos máximos f(x) y t(x): [1.875] [1.875]

# %% [markdown]
# Se puede observar en la gráfica cómo con el método de aceptación y rechazo, los puntos azules que están por debajo de f(x) la se pueden aceptar con la simulación.

# %% [markdown]
# ### <font> **Ejercicio 6:**
# > 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# ### Soluciones Ivan

# %%
# Código de solución 
N =500
x =np.arange(0,1,0.01)
plt.figure(figsize=[6,5])
f = lambda x: 30*(x**2 - 2*x**3 + x**4)
plt.title("Aceptación y Rechazo para $t(x)=a$",fontsize=14)
#plt.xlabel('Rango',fontsize=14)
#plt.ylabel('Densidad de probabilidad',fontsize=14)
plt.plot(x,f(x), label='f(x)',color="green",lw=4)
t = lambda x: a*np.ones([len(x)])
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
plt.plot(x,t(x),label='t(x)',color="blue",lw=4)
plt.legend()
R1 = np.random.rand(N)
R2 = np.random.rand(N)
Acep_rechazo(R1,R2,f,t)


plt.show()

# %% [markdown]
# ### Respuesta Ivan
# Los puntos aceptados estan representados en color azul mientras que los rechazados son los puntos coloridos los cuales al ser aceptados hacen referencia a que estan por debajo de la función $f(x)$ y los coloridos fuera de esta.

# %% [markdown]
# # Soluciones Ana

# %%
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo2(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    f_x = f(R1)
    t_x = t(R1)
    cont = np.zeros(len(R1))
    condition = R2*t_x <=f_x
    def a(i):
        nonlocal cont
        cont [i] = True if condition[i] else False 
    [a(i) for i in range(len(R1))]
    return cont

f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
# Función t -> Función constante
tsin= lambda x: max_f*np.sin(x*np.pi) # función sinoidal
tcons= lambda x: max_f*np.ones(len(x)) # función constante 

x = np.arange(0,1,0.01)  # Rango donde se graficará las funciones


# Validación del método
Ginv= lambda u:(1/np.pi)*np.arccos(-2*u+1)
U = np.random.rand(N)
R2 = Ginv(U)
R1 = np.random.rand(N)

print('El porcentaje de puntos de aceptación cuando se usa 𝑡(𝑥) constante', sum(Acep_rechazo2(R2,R1,f,tcons))/N)
print('El porcentaje de puntos de aceptación cuando se usa 𝑡(𝑥) un pulso senoidal', sum(Acep_rechazo2(R2,R1,f,tsin))/N)
# Out:
# El porcentaje de puntos de aceptación cuando se usa 𝑡(𝑥) constante 0.582
# El porcentaje de puntos de aceptación cuando se usa 𝑡(𝑥) un pulso senoidal 0.753

# %% [markdown]
# ### <font> **Ejercicio 7:**
# > 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %%
# Código de solución 
N = 500 
f = lambda x: 20*x*(1-x)**3
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
plt.figure(figsize=[6,5])
plt.plot(x,f(x), label='$f(x)=20x(1-x)^3$',color="g",lw=4)
plt.title('Aceptación y Rechazo de: $f(x)=20x(1-x)^3$',fontsize=14)
t = lambda x: a*np.ones([len(x)])
plt.plot(x,t(x),label='$t(x)=a$',color="y",lw=4)
plt.legend()
plt.grid()
R1 = np.random.rand(N)
R2 = np.random.rand(N)
Acep_rechazo(R2,R1,f,t)
plt.show()

# %% [markdown]
# ### Respuesta Ivan
# Gráfica de aceptación y rechazo utilizando una variabble aleatoria a partir de $f(x)=20x(1-x)^3$.

# %% [markdown]
# ## Soluciones Ana

# %%
# Función objetivo 
f = lambda x:20*x*(1-x)**3
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
# Función t -> Función constante
t = lambda x: max_f*np.ones(len(x)) # función constante

x = np.arange(0,1,0.01)  # Rango donde se graficará
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend();

N = 1000
R2 = np.random.rand(N)
R1 = np.random.rand(N)
# plt.show()
aleatorias = Acep_rechazo(R2,R1,f,t)
aleatorias
# Out:
# El máximo de f es: [2.109375]
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Se pueden observar los valores aceptados y rechazados con la nueva función.

# %% [markdown]
# ### <font> **Ejercicio 8:**
# Demostrar la validez de la siguiente ecuación si
# >$$X\sim binomial(n,p) \longrightarrow p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i},\quad i=0,1,\cdots,n$$
# >$$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i \longrightarrow \text{Hablar de las ventajas que sea recursiva}$$

# %% [markdown]
# # Soluciones Ivan

# %% [markdown]
# > Se sabe que:
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i $$
# > por lo que despejando:
# $$\frac{p_{i+1}}{p_i}=\frac{n-i}{i+1}\frac{p}{1-p} $$
# > Y por propieddes factoriales puedo sustituir:
# $$\frac{(n+1)!}{n!}=n+1 ; \frac{n!}{(n+1)!}=\frac{1}{n+1}$$
# > y:
# $$ (n-1)! = \frac{n!}{n} ; n!=n(1+n)!$$
# > Y tomando en cuenta que:
# >$$X\sim binomial(n,p) \longrightarrow p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i},\quad i=0,1,\cdots,n$$
# > Entonces simplificando obtenemos::
# $$\frac{p_{i+1}}{p_i} = \frac{p(n-i)!(-p+i)(i+1)^{n+1-i}}{(i+1)(n+1-i)(-p+1)^{n-i}}$$
#
# $$p_{i+1} = \frac{p(n-i)!(-p+i)(i+1)^{n+1-i}}{(i+1)(n+1-i)(-p+1)^{n-i}}p_i$$
#
# $$p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p}p_i$$

# %% [markdown]
# <font> es más fácil programar y necesita menos memoria computacional, es la ventaja de que sea recursiva ya que se vuelve menos compleja con eso reservamos los factoriales lo que nos hace mas eficientes en timepo

# %% [markdown]
# ## Soluciones Ana

# %% [markdown]
# $$\frac{p_{i+1}}{p_i} = \frac{n! p^{i+1}(1-p)^{n-i-1}}{(i+1)! (n-i-1)! }\frac{i!(n-i)!}{n! p^{i} (1-p)^{n-i}}$$
#
# $n!$ se simplifica con $n!$$
#
# $\frac{i!}{i+1!}$ se simplifica y queda $\frac{1}{i+1}$
#
# $\frac{p^{i+1}}{p^{i}}$ se simplifica y queda $\frac{p}{1}$
#
# $\frac{(1-p)^{n-i-1}}{(1-p)^{n-1}}$ se simplifica y queda $(1-p)^{-1}$, es decir, $\frac{1}{(1-p)}$
#
# $\frac{n-i!}{n-i-1!}$ se simplifica y queda $\frac{n-i}{1}$
#
# Después de hacer la simplificación nos queda esto
#
# $\frac{p_{i+1}}{p_i} = \frac{(n-i)p}{ (i+1)(1-p)}$
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# Computacionalmente la carga es mucho menor si lo hacemos de manera recursiva, esto facilita todos los procesos.

# %% [markdown]
# ### <font> **Ejercicio 9:**
# > 9. Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# >$$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
# > Demuestre matemáticamente que
# > $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
# > y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.
#
# Enlace: https://es.wikipedia.org/wiki/Distribuci%C3%B3n_de_Poisson

# %% [markdown]
# # Soluciones Ivan

# %% [markdown]
# >si:
# $$P(k+1) = \frac{\lambda}{K+1}P(k)$$
# > Entonces:
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda}{k+1}$$
# > Usando la fórmula recursiva para calcular $P(k+1)$ en términos de $P(k)$:
# $$\frac{P(k+1)}{P(k)} = \frac{\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}}$$
# > También se hace uso de la propiedad $$\frac{k!}{(k+1)!}=\frac{1}{k+1}$$
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda^{k+1}k!}{\lambda^{k}(k+1)!} = \frac{\lambda}{k+1}$$
#  Por lo que: <span style="color:red"> $$P(k+1) = \frac{\lambda}{k+1}P(k)$$

# %%
def Gen_distr_discreta(p_acum: 'P.Acumulada de la distribución a generar',
                       indices: 'valores reales a generar aleatoriamente',
                       N: 'cantidad de números aleatorios a generar'):
    
    U =np.random.rand(N)
    # Diccionario de valores aleatorios
    rand2reales = {i: idx for i, idx in enumerate(indices)}

    # Series de los valores aletorios
    y = pd.Series([sum([1 for p in p_acum if p < ui]) for ui in U]).map(rand2reales)

    return y
def plot_histogram_discrete(distribucion:'señal de varibles aleatorias de un distribución DISCRETA dada',
                            label:'label del legend a aparecer en el gráfica',
                            densidad:'por defecto regresa el histograma en densidad'=True):
    plt.figure(figsize=[8,4])
    y, x = np.histogram(distribucion, bins=len(set(distribucion)), density=densidad) 
    plt.bar(x[1:], y, label=label)
    plt.legend()
    plt.grid()
    plt.title('Poisson',fontsize=14)
    plt.xlabel('Rango',fontsize=14)
    plt.ylabel('Probabilidad',fontsize=14)
    plt.show()  
def poisson(l,k):
    z=np.zeros(k+1)
    z[0]=np.exp(-l)
    def z1(i):
        nonlocal z
        z[i+1]=z[i]*(l/(i+1))
    [z1(i) for i in range(k-1)]
    return np.cumsum(z)
N = 10000;k = 10
Poisson=poisson(5,5)


# Usando el método de la transformada inversa
pl= Gen_distr_discreta(Poisson,np.arange(0,k+1),N)    
plot_histogram_discrete(pl,"Distribución Poisson")

# %% [markdown]
# Esta es la representacion visulade la distribución de Poisson la cual muestra que estamos viendo una distribución discreta con una probabilidad de k sucesos.

# %% [markdown]
# # Soluciones Ana

# %% [markdown]
# $\frac{p_{k+1}}{p_k} = \frac{e^{-\lambda}(\lambda)^{k+1}}{k+1!} \frac{k!}{e^{-\lambda}(\lambda)^{k}}$
#
# $e^{-\lambda}$ se simplifica con $e^{-\lambda}$
#
# $\frac{k!}{k+1!}$ se simplifica y queda $\frac{1}{k+1}$
#
# $\frac{(\lambda)^{k+1}}{(\lambda)^{k}}$ se simplifica y queda $\frac{\lambda}{1}$
#
# Después de hacer la simplificación nos queda esto
#
# $\frac{p_{k+1}}{p_k}=\frac{\lambda}{k+1}$
#
# $$P(k+1)=\frac{\lambda}{k+1}P(k)$$

# %%
def Gen_distr_discreta(p_acum: 'P.Acumulada de la distribución a generar',
                       indices: 'valores reales a generar aleatoriamente',
                       N: 'cantidad de números aleatorios a generar'):
    
    U =np.random.rand(N)
    # Diccionario de valores aleatorios
    rand2reales = {i: idx for i, idx in enumerate(indices)}

    # Series de los valores aletorios
    y = pd.Series([sum([1 for p in p_acum if p < ui]) for ui in U]).map(rand2reales)

    return y
def plot_histogram_discrete(distribucion:'señal de varibles aleatorias de un distribución DISCRETA dada',
                            label:'label del legend a aparecer en el gráfica',
                            densidad:'por defecto regresa el histograma en densidad'=True):
    plt.figure(figsize=[8,4])
    y, x = np.histogram(distribucion, bins=len(set(distribucion)), density=densidad) 
    plt.bar(x[1:], y, label=label)
    plt.legend()
    plt.grid()
    plt.title('Poisson',fontsize=14)
    plt.xlabel('Rango',fontsize=14)
    plt.ylabel('Probabilidad',fontsize=14)
    plt.show()  
def poisson(l,k):
    z=np.zeros(k+1)
    z[0]=np.exp(-l)
    def z1(i):
        nonlocal z
        z[i+1]=z[i]*(l/(i+1))
    [z1(i) for i in range(k-1)]
    return np.cumsum(z)
N = 10000;k = 10
Poisson=poisson(5,5)


# Usando el método de la transformada inversa
pl= Gen_distr_discreta(Poisson,np.arange(0,k+1),N)    
plot_histogram_discrete(pl,"Distribución Poisson")
